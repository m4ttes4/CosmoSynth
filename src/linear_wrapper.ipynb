# %%
class LinearFitter:
    def __init__(self, model, **kwargs):
        self._model = model
    
    @property
    def model(self):
        return self._model
    
    def _residuals(self,theta,data,grid,error):
        return
